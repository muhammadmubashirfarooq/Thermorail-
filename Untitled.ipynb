# %%
import geopandas as gpd

# Load the generated dataset
gdf = gpd.read_file("public/southwest_temperature_mapped.geojson")

print("--- GEOSPATIAL TEST RESULTS ---")
print(f"Total Segments: {len(gdf):,}")
print(f"Null Values Found: {gdf['surface_temp_c'].isnull().sum()}")
print(f"Min Temperature: {gdf['surface_temp_c'].min()}°C")
print(f"Max Temperature: {gdf['surface_temp_c'].max()}°C")
print(f"Average Temperature: {gdf['surface_temp_c'].mean():.2f}°C")
print("\nFirst 3 Records:")
print(gdf[['segment_id', 'surface_temp_c', 'operator']].head(3))
# Out:
# --- GEOSPATIAL TEST RESULTS ---
# Total Segments: 45,955
# Null Values Found: 0
# Min Temperature: 38.0°C
# Max Temperature: 60.5°C
# Average Temperature: 44.85°C
#
# First 3 Records:
#   segment_id  surface_temp_c     operator
# 0   SW_00001            47.4  unavailable
# 1   SW_00002            47.4  unavailable
# 2   SW_00003            47.4  unavailable
